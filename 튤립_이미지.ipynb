# %% [markdown]
# <a href="https://colab.research.google.com/github/jewelry715/github_test/blob/master/%ED%8A%A4%EB%A6%BD_%EC%9D%B4%EB%AF%B8%EC%A7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
# !wget http://download.tensorflow.org/example_images/flower_photos.tgz
# !tar -xvzf flower_photos.tgz
# Out:
# --2020-07-21 12:37:56--  http://download.tensorflow.org/example_images/flower_photos.tgz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.143.128, 2a00:1450:4013:c03::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.143.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228813984 (218M) [application/x-compressed-tar]
# Saving to: ‘flower_photos.tgz’
#
# flower_photos.tgz   100%[===================>] 218.21M  62.1MB/s    in 3.5s
#
# 2020-07-21 12:37:59 (62.1 MB/s) - ‘flower_photos.tgz’ saved [228813984/228813984]
#
# flower_photos/
# flower_photos/roses/
# flower_photos/roses/14810868100_87eb739f26_m.jpg
# flower_photos/roses/1446090416_f0cad5fde4.jpg
# flower_photos/roses/15319767030_e6c5602a77_m.jpg
# flower_photos/roses/15032112248_30c5284e54_n.jpg
# flower_photos/roses/7211616670_2d49ecb3a5_m.jpg
# flower_photos/roses/15674450867_0ced942941_n.jpg
# flower_photos/roses/17158274118_00ec99a23c.jpg
# ...

# %%
# !wget https://github.com/tensorflow/hub/raw/r0.1/examples/image_retraining/retrain.py
# !ls -al
# Out:
# --2020-07-21 12:38:14--  https://github.com/tensorflow/hub/raw/r0.1/examples/image_retraining/retrain.py
# Resolving github.com (github.com)... 140.82.118.3
# Connecting to github.com (github.com)|140.82.118.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/tensorflow/hub/r0.1/examples/image_retraining/retrain.py [following]
# --2020-07-21 12:38:14--  https://raw.githubusercontent.com/tensorflow/hub/r0.1/examples/image_retraining/retrain.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55279 (54K) [text/plain]
# Saving to: ‘retrain.py’
#
# retrain.py          100%[===================>]  53.98K  --.-KB/s    in 0.007s
#
# ...

# %%
# !python retrain.py --image_dir flower_photos
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# I0721 12:39:28.190217 140433708119936 retrain.py:354] Creating bottleneck at /tmp/bottleneck/sunflowers/8174941335_56389b53e9_n.jpg_https~tfhub.dev~google~imagenet~inception_v3~feature_vector~1.txt
# INFO:tensorflow:Creating bottleneck at /tmp/bottleneck/sunflowers/15495578821_92c6d14252_n.jpg_https~tfhub.dev~google~imagenet~inception_v3~feature_vector~1.txt
# I0721 12:39:28.207133 140433708119936 retrain.py:354] Creating bottleneck at /tmp/bottleneck/sunflowers/15495578821_92c6d14252_n.jpg_https~tfhub.dev~google~imagenet~inception_v3~feature_vector~1.txt
# INFO:tensorflow:Creating bottleneck at /tmp/bottleneck/sunflowers/2588453601_66f2a03cca_n.jpg_https~tfhub.dev~google~imagenet~inception_v3~feature_vector~1.txt
# I0721 12:39:28.224343 140433708119936 retrain.py:354] Creating bottleneck at /tmp/bottleneck/sunflowers/2588453601_66f2a03cca_n.jpg_https~tfhub.dev~google~imagenet~inception_v3~feature_vector~1.txt
# ...

# %%
# !ls /tmp -al

# %%
# !wget https://images.homedepot-static.com/productImages/d51e274c-e719-46f4-a0ad-7c2785b0e07a/svn/van-zyverden-flower-bulbs-21597-64_1000.jpg
# !mv van-zyverden-flower-bulbs-21597-64_1000.jpg tulip.jpg
# Out:
# --2020-07-21 12:44:40--  https://images.homedepot-static.com/productImages/d51e274c-e719-46f4-a0ad-7c2785b0e07a/svn/van-zyverden-flower-bulbs-21597-64_1000.jpg
# Resolving images.homedepot-static.com (images.homedepot-static.com)... 35.186.226.36
# Connecting to images.homedepot-static.com (images.homedepot-static.com)|35.186.226.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 130993 (128K) [image/jpeg]
# Saving to: ‘van-zyverden-flower-bulbs-21597-64_1000.jpg’
#
# van-zyverden-flower 100%[===================>] 127.92K   476KB/s    in 0.3s
#
# 2020-07-21 12:44:41 (476 KB/s) - ‘van-zyverden-flower-bulbs-21597-64_1000.jpg’ saved [130993/130993]

# %%
# !wget https://raw.githubusercontent.com/tensorflow/tensorflow/master/tensorflow/examples/label_image/label_image.py
# Out:
# --2020-07-21 12:45:12--  https://raw.githubusercontent.com/tensorflow/tensorflow/master/tensorflow/examples/label_image/label_image.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4697 (4.6K) [text/plain]
# Saving to: ‘label_image.py’
#
# label_image.py      100%[===================>]   4.59K  --.-KB/s    in 0s
#
# 2020-07-21 12:45:12 (83.4 MB/s) - ‘label_image.py’ saved [4697/4697]

# %%
# !python label_image.py --graph=/tmp/output_graph.pb --labels=/tmp/output_labels.txt --input_layer=Placeholder --output_layer=final_result --image=tulip.jpg
# Out:
# WARNING:tensorflow:From label_image.py:28: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From label_image.py:45: The name tf.read_file is deprecated. Please use tf.io.read_file instead.
#
# WARNING:tensorflow:From label_image.py:57: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# 2020-07-21 12:45:17.969354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-21 12:45:17.984403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-21 12:45:17.984983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# ...
